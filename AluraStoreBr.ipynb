# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielearieiv/challenge_alurastore/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Relatório Alura Store ✅**
#
# **Objetivo:** Apoiar o Sr. João na decisão de qual loja da rede Alura Store vender, com o intuito de iniciar um novo empreendimento, por meio da identificação da loja com menor eficiência.
#
#   Foram utilizados os seguintes dados para a análise:
#
# * Faturamento;
# * Vendas por Categoria;
# * Média de Avaliação por Loja;
# * Produtos Mais e Menos Vendidos;
# * Frete Médio por Loja.
#
#
# ## 📈 Faturamento
#
#
# ---
#
# ### Resumo por loja:
# * Loja 1: Apresenta o maior faturamento total de R$ 1,534,509.12, entretanto, não se manteve lider de faturamento em todos os anos analisados, houveram quedas significativas ao passar dos 3 primeiros anos analisados.
#
# * Loja 2: É a loja com o faturamento mais estável e apresentou crescimento ao passar dos anos.
#
# * Loja 3: Apresenta aumento significativo de 2020 para 2021, entretanto, esse aumento não se mantem no ano seguinte. É a loja com o segundo pior faturamento.
#
# * Loja 4: Apresenta o pior faturamento e queda significativa ao passar dos anos.
#
# ### **Conclusão:** As lojas 3 e 4 apresentaram um faturamento abaixo da média .
#
# ![image.png](data:image/png;base64,...)
#
# ## 🏷️ Vendas por categoria
# ------
#
# A análise das vendas por categoria mostrou que o Top 5 das categorias mais vendidas, em todas as lojas, está concentrado nos segmentos de Móveis, Eletrônicos, Brinquedos, Eletrodomésticos e Esporte e Lazer.
#
# As lojas 1, 2 e 3 seguem exatamente a mesma ordem de vendas por categoria, enquanto a loja 4 apresenta uma leve variação nas duas últimas posições. Essa diferença indica que as vendas de qualquer loja individual provavelmente não afetarão de forma significativa a distribuição geral das categorias, preservando o padrão predominante em toda a rede.
#
# ![image.png](data:image/png;base64,...)
#
# ##✅ MÉDIA DE AVALIAÇÃO POR LOJA
# ----------
#
# A análise indica que, apesar de todas as lojas apresentarem níveis de satisfação relativamente elevados, a Loja 1 destaca-se por estar ligeiramente abaixo das demais, evidenciando uma oportunidade clara para melhorias.
#
# ![image.png](data:image/png;base64,...)
#
# ## 📦 PRODUTOS MAIS E MENOS VENDIDOS
# --------
# As quatro lojas apresentam perfis de venda distintos, refletindo diferenças no interesse e demanda dos consumidores por categorias variadas. Produtos funcionais e essenciais, como eletrodomésticos (micro-ondas, TV UHD) e móveis (guarda-roupas, cama box, banquetas), dominam as vendas em quase todas as lojas, indicando uma forte preferência por itens de uso diário e alto valor agregado.
#
# Por outro lado, os produtos menos vendidos — como headset, celular ABXY, jogo de tabuleiro, blocos de montar e guitarra — tendem a ser mais específicos ou voltados para nichos, o que sugere que há espaço para revisar estratégias de marketing, exposição ou até portfólio para esses itens.
#
# Oportunidades claras:
#
# A Loja 2, com destaque para o livro “Iniciando em programação”, indica potencial para explorar produtos educacionais e de interesse em tecnologia, setor em crescimento. Investir em produtos complementares pode ampliar essa fatia.
#
# Lojas com produtos menos vendidos em categorias de nicho podem se beneficiar de promoções, bundles ou reposicionamento para aumentar a rotatividade desses itens.
#
# Analisar o perfil de cliente de cada loja permitirá ajustar o mix de produtos para maximizar vendas e evitar estoques parados.
#
# Em resumo, as vendas refletem uma base sólida em categorias tradicionais, com oportunidades estratégicas para expandir em nichos e ajustar portfólio conforme o perfil local de consumidores.
#
# ## 🚚 FRETE MÉDIO POR LOJA
# --------
# As médias de frete das quatro lojas apresentam uma variação relativamente pequena, indo de R$ 31,28 (Loja 4) a R$ 34,69 (Loja 1). Essa diferença de aproximadamente R$ 3,40 sugere que o custo de frete está bastante homogêneo entre as unidades, sem grandes disparidades que possam impactar significativamente o comportamento do consumidor.
#
# No entanto, algumas considerações importantes:
#
# Loja 1 possui a maior média de frete (R$ 34,69), o que pode representar um ponto de atenção para a competitividade, especialmente se seus clientes forem mais sensíveis a custos extras. Essa diferença, ainda que pequena, pode influenciar na decisão de compra em um mercado competitivo.
#
# Loja 4 tem o frete mais baixo (R$ 31,28), o que pode ser usado como vantagem competitiva em comunicação e estratégias de marketing, atraindo clientes preocupados com o custo total da compra.
#
# A uniformidade dos valores sugere que as lojas provavelmente compartilham a mesma estrutura logística ou políticas de frete semelhantes, mas ainda há espaço para otimizar custos, especialmente na Loja 1, para alinhá-la melhor às demais.
#
# ### Recomendações:
#
# Avaliar a possibilidade de redução do frete na Loja 1, seja por negociação com transportadoras, otimização de rotas ou pacotes promocionais, para evitar perder clientes para lojas com fretes mais baratos.
#
# Explorar estratégias para destacar o frete mais baixo da Loja 4 como diferencial competitivo em campanhas locais.
#
# Monitorar o impacto do custo do frete nas vendas e no comportamento do cliente para ajustar políticas conforme a resposta do mercado.
#
#
# ![image.png](data:image/png;base64,...)
#
# ## ✅ Conclusão Geral
# A partir da análise dos dados das quatro lojas da rede Alura Store, foi possível identificar pontos fortes e fragilidades em diferentes aspectos de desempenho: faturamento, composição de vendas, avaliação dos clientes, produtos mais e menos vendidos e frete médio.
#
# A Loja 4 destaca-se negativamente em diversos critérios — apresenta o pior faturamento, queda contínua ao longo dos anos, e ligeiras diferenças no padrão de vendas por categoria, o que pode indicar baixa aderência ao perfil de consumo da rede. Por outro lado, possui o frete mais competitivo, o que pode ser explorado como um diferencial.
#
# A Loja 3 também apresentou desempenho abaixo da média em termos de faturamento e vendas, mas com um comportamento mais instável, o que sugere possibilidade de recuperação com ajustes estratégicos.
#
# A Loja 1, embora apresente o maior faturamento, também tem maior média de frete e menor avaliação média, o que pode comprometer sua sustentabilidade no longo prazo se esses pontos não forem ajustados.
#
# A Loja 2, por sua vez, mostra-se como a mais estável e consistente: crescimento de faturamento ao longo dos anos, boa avaliação, produtos de alto giro e frete competitivo, sendo a loja com maior potencial de referência para a rede.
#
# ## 🧭 **Recomendações para o Sr. João:**
# Considerar a Loja 4 como principal candidata para venda, dado seu baixo desempenho geral e perda contínua de relevância. A venda poderia liberar recursos para investir em lojas com maior potencial ou iniciar um novo empreendimento mais promissor.
#
# Reavaliar a estratégia da Loja 1, especialmente em relação ao custo do frete e à experiência do cliente. Pequenos ajustes podem manter sua liderança em faturamento e evitar perda de competitividade.
#
# Aproveitar os dados positivos da Loja 2 como modelo de boas práticas para replicar em outras unidades da rede, principalmente no mix de produtos e gestão de crescimento.
#
# Investir em ações de recuperação para a Loja 3, analisando o que motivou o pico de crescimento em 2021 e buscando replicar esse desempenho.

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
#Criando um dicionário (lojas_dict) onde cada chave é o nome da loja e cada valor é um DataFrame com os dados dessa loja.
#Isso permite percorrer todas as lojas usando for nome, df in lojas_dict.items(), simplificando o código.

lojas_dict = {
    "Loja 1": loja,
    "Loja 2": loja2,
    "Loja 3": loja3,
    "Loja 4": loja4
}

#Calculando o faturamento total de cada loja (total da coluna Preço com .sum())
for nome, df in lojas_dict.items():
    faturamento = df["Preço"].sum()

    print(f"O faturamento total da loja {nome} é: R$ {faturamento:,.2f}")

#Salvando esse total em um dicionário para usar depois nos gráficos
faturamentos = []
for nome, df in lojas_dict.items():
    faturamento = df["Preço"].sum()
    faturamentos.append(faturamento)


# Variáveis para apresentação anual
#Criei uma lista com os DataFrames das lojas.
#Converti a coluna de datas para o tipo datetime.
#Criei uma nova coluna com o ano da compra.
#Agrupei por ano e somei os preços.
#Salvei os totais em uma lista (faturamento_anual) com os resultados por loja.
#pd.to_datetime() para normalizar datas.
#.dt.year para extrair apenas o ano.
#.groupby() + .sum() para fazer agregações por categoria (ano).

dfs = [loja, loja2, loja3, loja4]
nomes = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
faturamento_anual = []

# Soma de cada loja anualmente
for df, nome in zip(dfs, nomes):
    df['Data da Compra'] = pd.to_datetime(df['Data da Compra'], dayfirst=True)
    df['Ano da Compra'] = df['Data da Compra'].dt.year
    faturamento = df.groupby('Ano da Compra')['Preço'].sum()
    faturamento_anual.append(faturamento)

    print(f"Faturamento anual da {nome}:")
    for ano, valor in faturamento.items():
        print(f"  Ano {ano}: R$ {valor:,.2f}")
    print()
# Out:
# O faturamento total da loja Loja 1 é: R$ 1,534,509.12
# O faturamento total da loja Loja 2 é: R$ 1,488,459.06
# O faturamento total da loja Loja 3 é: R$ 1,464,025.03
# O faturamento total da loja Loja 4 é: R$ 1,384,497.58
# Faturamento anual da Loja 1:
#   Ano 2020: R$ 491,911.51
#   Ano 2021: R$ 482,829.91
#   Ano 2022: R$ 422,086.24
#   Ano 2023: R$ 137,681.46
#
# Faturamento anual da Loja 2:
#   Ano 2020: R$ 427,288.25
#   Ano 2021: R$ 468,288.89
#   Ano 2022: R$ 477,635.56
#   Ano 2023: R$ 115,246.36
#
# Faturamento anual da Loja 3:
#   Ano 2020: R$ 428,943.09
#   Ano 2021: R$ 483,938.91
#   Ano 2022: R$ 467,250.70
#   Ano 2023: R$ 83,892.33
#
# Faturamento anual da Loja 4:
#   Ano 2020: R$ 441,129.52
#   Ano 2021: R$ 463,763.27
#   Ano 2022: R$ 402,961.23
#   Ano 2023: R$ 76,643.56

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Nomes das lojas e seus faturamentos
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [sum(f.values) for f in faturamento_anual]
valores_por_loja = [list(f.values) for f in faturamento_anual]
anos_todos = sorted(set().union(*[f.index for f in faturamento_anual]))

cores = ['#39A845', '#FF7F50', '#FFD700', '#FF69B4']

# Criar figura
fig, ax = plt.subplots(1, 2, figsize=(20, 5))

# Gráfico de Barras Horizontais – Faturamento Total
bars = ax[0].barh(lojas, faturamentos, color=cores)
ax[0].set_title('Faturamento Total por Loja')
ax[0].xaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax[0].set_xlim(min(faturamentos) * 0.95, max(faturamentos) * 1.05)

# Linha da média
media_faturamento = sum(faturamentos) / len(faturamentos)
ax[0].axvline(media_faturamento, color='darkgreen', linestyle='--', linewidth=2,
              label=f'Média: R$ {media_faturamento:,.2f}')
ax[0].legend()

# Anotações nas barras
for bar in bars:
    width = bar.get_width()
    ax[0].text(width + 10000, bar.get_y() + bar.get_height() / 2,
               f'R$ {width:,.2f}', ha='left', va='center', fontsize=9)

# Gráfico de Linhas – Faturamento Anual por Loja
for i, serie in enumerate(faturamento_anual):
    anos = serie.index
    valores = serie.values
    ax[1].plot(anos, valores, marker='o', label=lojas[i], color=cores[i])
    for ano, valor in zip(anos, valores):
        ax[1].text(ano, valor, f'{valor:,.0f}', color=cores[i], ha='center', va='bottom', fontsize=9)

ax[1].set_xticks(anos_todos)
ax[1].set_xticklabels(anos_todos)
ax[1].set_title('Faturamento Anual por Loja')
ax[1].legend(title='Lojas')
ax[1].yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Lista com os DataFrames das lojas
lojas = [loja, loja2, loja3, loja4]

# Mostrar o Top 5 de categorias por loja
for idx, loja_df in enumerate(lojas, start=1):
    top5 = loja_df['Categoria do Produto'].value_counts().head(5)
    print(f'As categorias mais populares (Top 5) da Loja {idx} são:\n{top5}')

    if idx < len(lojas):
        print()  # Linha em branco entre lojas
# Out:
# As categorias mais populares (Top 5) da Loja 1 são:
# Categoria do Produto
# moveis              465
# eletronicos         448
# brinquedos          324
# eletrodomesticos    312
# esporte e lazer     284
# Name: count, dtype: int64
#
# As categorias mais populares (Top 5) da Loja 2 são:
# Categoria do Produto
# moveis              442
# eletronicos         422
# brinquedos          313
# eletrodomesticos    305
# esporte e lazer     275
# Name: count, dtype: int64
#
# As categorias mais populares (Top 5) da Loja 3 são:
# Categoria do Produto
# moveis              499
# eletronicos         451
# brinquedos          315
# eletrodomesticos    278
# esporte e lazer     277
# Name: count, dtype: int64
#
# As categorias mais populares (Top 5) da Loja 4 são:
# Categoria do Produto
# moveis              480
# eletronicos         451
# brinquedos          338
# esporte e lazer     277
# eletrodomesticos    254
# Name: count, dtype: int64

# %%
import seaborn as sns

# Lista com os DataFrames das lojas
lojas = [loja, loja2, loja3, loja4]
venda_categorias = []

# Coletar os Top 5 de cada loja e armazenar como Series (index = categoria, values = contagem)
for loja_df in lojas:
    top5 = loja_df['Categoria do Produto'].value_counts().head(5)
    venda_categorias.append(top5)

# Combinar as Series em um DataFrame (categorias como índice, lojas como colunas)
df_top5 = pd.concat(venda_categorias, axis=1)
df_top5.columns = [f'Loja {i+1}' for i in range(len(lojas))]

# Substituir NaN por 0 (caso uma categoria não esteja no Top 5 de todas as lojas)
df_top5.fillna(0, inplace=True)

# Criar o heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_top5, annot=True, cmap='Greens', fmt='g')
plt.title('Top 5 Categorias Mais Vendidas por Loja')
plt.ylabel('Categoria do Produto')
plt.xlabel('Loja')
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
import pandas as pd

nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Criar um DataFrame vazio para juntar os dados
media_anual_df = pd.DataFrame()

for i, df in enumerate(dfs):
    medias_ano = df.groupby('Ano da Compra')['Avaliação da compra'].mean().round(2)
    media_anual_df[nomes_lojas[i]] = medias_ano

print("Média Anual da Avaliação por Loja:\n")
print(media_anual_df.to_string())

# Criar DataFrame para as quantidades de avaliações
avaliacao_notas_df = pd.DataFrame()

for i, df in enumerate(dfs):
    counts = df['Avaliação da compra'].value_counts().sort_index()
    avaliacao_notas_df[nomes_lojas[i]] = counts

avaliacao_notas_df = avaliacao_notas_df.fillna(0).astype(int)

print("\nQuantidade de Avaliações por Nota:\n")
print(avaliacao_notas_df.to_string())
# Out:
# Média Anual da Avaliação por Loja:
#
#                Loja 1  Loja 2  Loja 3  Loja 4
# Ano da Compra
# 2020             3.93    4.04    4.12    4.02
# 2021             3.96    4.00    3.93    3.96
# 2022             4.04    4.10    4.09    3.97
# 2023             3.96    3.96    4.08    4.17
#
# Quantidade de Avaliações por Nota:
#
#                      Loja 1  Loja 2  Loja 3  Loja 4
# Avaliação da compra
# 1                       319     273     297     310
# 2                        86      93      79      85
# 3                       218     209     193     210
# 4                       444     482     434     453
# 5                      1292    1302    1356    1300

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Supondo que dfs é a lista dos seus dataframes [loja, loja2, loja3, loja4]
nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Pegando todas as notas possíveis (de 1 a 5, por exemplo)
notas_possiveis = [1, 2, 3, 4, 5]

# Criar DataFrame vazio para armazenar contagem das avaliações
avaliacao_notas_df = pd.DataFrame(index=notas_possiveis)

# Preenchendo o DataFrame com contagem de avaliações para cada loja
for i, df in enumerate(dfs):
    contagem = df['Avaliação da compra'].value_counts()
    # Garantir que todas as notas possíveis estejam presentes no índice
    contagem = contagem.reindex(notas_possiveis, fill_value=0)
    avaliacao_notas_df[nomes_lojas[i]] = contagem

n_lojas = len(nomes_lojas)
n_notas = len(notas_possiveis)


cores = ['#39A845', '#FF7F50', '#FFD700', '#FF69B4']
x = np.arange(n_notas)  # posição no eixo x para cada nota
largura = 0.2  # largura das barras

fig, ax = plt.subplots(figsize=(10, 6))

# Desenhar barras agrupadas para cada loja
for i in range(n_lojas):
    ax.bar(x + i*largura, avaliacao_notas_df[nomes_lojas[i]], width=largura, label=nomes_lojas[i], color=cores[i])

# Configurações do gráfico
ax.set_xticks(x + largura * (n_lojas - 1) / 2)
ax.set_xticklabels(notas_possiveis)
ax.set_xlabel('Nota da Avaliação')
ax.set_ylabel('Quantidade de Avaliações')
ax.set_title('Distribuição das Avaliações por Loja')
ax.legend(title='Lojas')

# Mostrar valor no topo das barras para facilitar leitura
for i in range(n_lojas):
    for j in range(n_notas):
        valor = avaliacao_notas_df[nomes_lojas[i]].iloc[j]
        ax.text(x[j] + i*largura, valor + 5, str(valor), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
#Quantidade de produtos vendidos
venda_produtos = [
    loja['Produto'].value_counts(),
    loja2['Produto'].value_counts(),
    loja3['Produto'].value_counts(),
    loja4['Produto'].value_counts()]

#Variavéis para lista de produtos mais e menos vendidos
produtos_mais_vendidos = []
produtos_menos_vendidos = []

#Extração dos produtos mais e menos vendidos por loja
for vendas in venda_produtos:
    max_vendas = vendas.max()
    min_vendas = vendas.min()
    produtos_max = vendas[vendas == max_vendas]
    produtos_min = vendas[vendas == min_vendas]
    produtos_mais_vendidos.append(produtos_max)
    produtos_menos_vendidos.append(produtos_min)

#Apresentação do resultado
for i in range(len(produtos_mais_vendidos)):
    print(f"Loja {i + 1} - Produtos mais vendidos:")
    for produto, quantidade in produtos_mais_vendidos[i].items():
        print(f" - {produto}: {quantidade} vendas")
    print()

    print(f"Loja {i + 1} - Produtos menos vendidos:")
    for produto, quantidade in produtos_menos_vendidos[i].items():
        print(f" - {produto}: {quantidade} vendas")
    print()
    if i > 2:
        continue
    print("-" * 40)
    print()
# Out:
# Loja 1 - Produtos mais vendidos:
#  - Micro-ondas: 60 vendas
#  - TV Led UHD 4K: 60 vendas
#  - Guarda roupas: 60 vendas
#
# Loja 1 - Produtos menos vendidos:
#  - Headset: 33 vendas
#  - Celular ABXY: 33 vendas
#
# ----------------------------------------
#
# Loja 2 - Produtos mais vendidos:
#  - Iniciando em programação: 65 vendas
#
# Loja 2 - Produtos menos vendidos:
#  - Jogo de tabuleiro: 32 vendas
#
# ----------------------------------------
#
# Loja 3 - Produtos mais vendidos:
#  - Kit banquetas: 57 vendas
#
# Loja 3 - Produtos menos vendidos:
#  - Blocos de montar: 35 vendas
#
# ----------------------------------------
#
# Loja 4 - Produtos mais vendidos:
#  - Cama box: 62 vendas
#
# Loja 4 - Produtos menos vendidos:
#  - Guitarra: 33 vendas

# %%
import pandas as pd
import plotly.express as px

# Lista com nomes das lojas
lojas_nomeadas = [f'Loja {i+1}' for i in range(len(venda_produtos))]

# Montar os dados dos produtos mais e menos vendidos
dados = []

for i in range(len(produtos_mais_vendidos)):
    for produto, qtd in produtos_mais_vendidos[i].items():
        dados.append({'Loja': lojas_nomeadas[i], 'Produto': produto, 'Tipo': 'Mais Vendido', 'Quantidade': qtd})
    for produto, qtd in produtos_menos_vendidos[i].items():
        dados.append({'Loja': lojas_nomeadas[i], 'Produto': produto, 'Tipo': 'Menos Vendido', 'Quantidade': qtd})

# Criar DataFrame
df_vendas_extremos = pd.DataFrame(dados)

# Treemap com cores válidas para o Plotly
fig = px.treemap(
    df_vendas_extremos,
    path=['Loja', 'Produto'],
    values='Quantidade',
    color='Quantidade',
    color_continuous_scale='rainbow',
    title='Produtos Mais e Menos Vendidos por Loja'
)

fig.update_layout(margin=dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
#Média do frete por loja
valor_frete = [
    round(loja['Frete'].mean(),2),
    round(loja2['Frete'].mean(),2),
    round(loja3['Frete'].mean(),2),
    round(loja4['Frete'].mean(),2)]

#Váriavel para média anualmente
freteanual = []

#Média de cada loja anualmente
for i in dfs:
  agrupamento = i.groupby('Ano da Compra')['Frete'].mean()
  freteanual.append(agrupamento.round(2))

media_frete = round((loja['Frete'].sum() + loja2['Frete'].sum() + loja3['Frete'].sum() + loja4['Frete'].sum()) / (len(loja['Frete']) + len(loja2['Frete']) + len(loja3['Frete']) + len(loja4['Frete'])),2)

#Apresentação do resultado
for i in range(len(valor_frete)):
  print(f'A média de frete da Loja {i+1} é de R$ {valor_frete[i]}')
# Out:
# A média de frete da Loja 1 é de R$ 34.69
# A média de frete da Loja 2 é de R$ 33.62
# A média de frete da Loja 3 é de R$ 33.07
# A média de frete da Loja 4 é de R$ 31.28

# %%
import matplotlib.pyplot as plt

lojas = [f'Loja {i+1}' for i in range(len(valor_frete))]

plt.figure(figsize=(8,5))
plt.bar(lojas, valor_frete, color='springgreen')
plt.title('Média do Frete por Loja')
plt.ylabel('Valor médio do frete (R$)')
plt.xlabel('Loja')
plt.show()
